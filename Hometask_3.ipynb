# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("http://www.scipy-lectures.org/_downloads/populations.txt")
plt.plot(data[:, 0], data[:, 1], label = 'hare')
plt.plot(data[:, 0], data[:, 2], label = 'lynx')
plt.plot(data[:, 0], data[:, 3], label = 'carrot')
plt.xticks(np.arange(np.min(data[:, 0]), np.max(data[:, 0]), 3))
plt.legend()
plt.show()

# %%
plt.plot(data[:, 0][data[:, 1] > 50000], data[:, 1][data[:, 1] > 50000], label = 'hare')
plt.plot(data[:, 0][data[:, 2] > 50000], data[:, 2][data[:, 2] > 50000], label = 'lynx')
plt.plot(data[:, 0][data[:, 3] > 50000], data[:, 3][data[:, 3] > 50000], label = 'carrot')

_s = 100
plt.scatter(data[:, 0][np.argmax(data[:, 1])], np.max(data[:, 1]), s=_s)
plt.scatter(data[:, 0][np.argmax(data[:, 2])], np.max(data[:, 2]), s=_s)
plt.scatter(data[:, 0][np.argmax(data[:, 3])], np.max(data[:, 3]), s=_s)

plt.legend()
plt.show()

#plt.scatter(data[:, 0][data[:, 1] > 50000],data[:, 1][data[:, 1] > 50000], label = 'hare')
#plt.scatter(data[:, 0][data[:, 2] > 50000],data[:, 2][data[:, 2] > 50000], label = 'lynx')
#plt.scatter(data[:, 0][data[:, 3] > 50000],data[:, 3][data[:, 3] > 50000], label = 'carrot')
#plt.scatter(years[lynxes > 50000], lynxes[lynxes > 50000], marker='x')
#plt.scatter(years[carrots > 50000], carrots[carrots > 50000], marker='x')

# %%
sum = data[:, 1] + data[:, 2]
plt.bar(data[:, 0], (data[:, 1] / sum), label = 'hare')
plt.bar(data[:, 0], (data[:, 2] / sum), label = 'lynx', bottom = data[:, 1] / sum)
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(1, 3)
axs[0].hist(data[:, 1], rwidth = 0.6)
axs[0].axvline(np.mean(data[:, 1]), color = 'r')
axs[0].set_title("hare")

axs[1].hist(data[:, 2], rwidth = 0.6)
axs[1].axvline(np.mean(data[:, 2]), color = "r")
axs[1].set_title("lynx")

axs[2].hist(data[:, 3], rwidth = 0.6)
axs[2].axvline(np.mean(data[:, 3]), color = 'r')
axs[2].set_title("carrot")
fig.tight_layout(pad = 0.5)

plt.show()

# %%
res = np.where(data[:, 1] > data[:, 2], "H", "L")
print(res)
# Out:
# ['H' 'H' 'H' 'H' 'L' 'L' 'L' 'H' 'H' 'H' 'H' 'H' 'H' 'H' 'H' 'L' 'L' 'L'
#  'H' 'H' 'H']

# %%
plt.pie([np.count_nonzero(res == 'H'), np.count_nonzero(res == "L")], labels = ['H', 'L'])
plt.show()

# %%
change = data[1:, 1] - data[:-1, 1]
plt.plot(data[1:, 0], data[1:, 2], label = "lynxes")
plt.plot(data[1:, 0], change, label = "change in hare")
plt.legend()
cov = 1 / (data.shape[0] - 2) * np.dot(change - np.mean(change), data[1:, 2] - np.mean(data[1:, 2]))
corr = cov / (np.std(change) * np.std(data[1:, 2]))
print(corr)
# Out:
# -0.8941896424901974

# %%
plt.scatter(data[:, 3], data[:, 1], label = "hares vs carrots")
plt.legend()
plt.show()
plt.scatter(data[:, 2], data[:, 1], label = "hares vs lynxes")
plt.legend()
plt.show()

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

model = LinearRegression().fit(data[:-1, 2:], data[:-1,1])

res = model.predict(data[-1, 2:].reshape(1, 2)) / data[-1, 1]

print(*res)
# Out:
# 1.4600048350575765
